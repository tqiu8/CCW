# %%
from votesmart import votesmart
from collections import OrderedDict 
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests
import json
import re

# %%
votesmart.apikey = 'dc4f937d022863a94d09d5b16be069a5'
API_KEY = 'AIzaSyDI5xmuZxkonbNuR7_oLsb7aVqLZTuXQs0'

# %%
state_list = votesmart.state.getStateIDs()
state_list = [[s.name, s.stateId] for s in state_list]
states_df = pd.DataFrame(data=state_list, columns=['name', 'stateId'])
states_df
# Out:
#                     name stateId
# 0               National      NA
# 1         American Samoa      AS
# 2                Florida      FL
# 3               Michigan      MI
# 4               Missouri      MO
# 5                Montana      MT
# 6                  Idaho      ID
# 7   District of Columbia      DC
# 8                Georgia      GA
# 9                 Hawaii      HI
# 10               Indiana      IN
# 11             Minnesota      MN
# 12           Connecticut      CT
# 13              Delaware      DE
# 14                  Iowa      IA
# 15              Illinois      IL
# 16        North Carolina      NC
# 17              New York      NY
# 18          Pennsylvania      PA
# 19                  Ohio      OH
# 20                Alaska      AK
# 21              Arkansas      AR
# 22            California      CA
# 23              Colorado      CO
# 24                Kansas      KS
# 25               Arizona      AZ
# 26                Oregon      OR
# 27               Alabama      AL
# 28          North Dakota      ND
# 29          Rhode Island      RI
# 30        South Carolina      SC
# 31          South Dakota      SD
# 32                 Texas      TX
# 33             Tennessee      TN
# 34                  Utah      UT
# 35         West Virginia      WV
# 36               Wyoming      WY
# 37             Wisconsin      WI
# 38              Oklahoma      OK
# 39              Nebraska      NE
# 40            Washington      WA
# 41         New Hampshire      NH
# 42                 Maine      ME
# 43              Maryland      MD
# 44            New Mexico      NM
# 45                Nevada      NV
# 46         Massachusetts      MA
# 47               Vermont      VT
# 48                  Guam      GU
# 49           Puerto Rico      PR
# 50                Virgin      VI
# 51              Kentucky      KY
# 52              Virginia      VA
# 53            New Jersey      NJ
# 54           Mississippi      MS
# 55             Louisiana      LA

# %%
offices = votesmart.office.getOfficesByType("C")
offices[0].officeId
# Out:
# u'5'

# %%
getByZip = votesmart.candidates.getByZip
getByOfficeState = votesmart.candidates.getByOfficeState

# %%
getByZip({"zip5":"02125", "stageId": "G"})
# Out:
# ---------------------------------------------------------------------------
# VotesmartApiError                         Traceback (most recent call last)
# <ipython-input-329-e92669dc5021> in <module>()
# ----> 1 getByZip({"zip5":"02125", "stageId": "G"})
#
# //anaconda3/envs/py27/lib/python2.7/site-packages/votesmart.pyc in getByZip(zip5, zip4)
#
# //anaconda3/envs/py27/lib/python2.7/site-packages/votesmart.pyc in _apicall(func, params)
#
# VotesmartApiError: ZIP code has not been provided.

# %%
def get_candidates(func, params, office):
    all_candidates = []
    if (office):
        for o in offices:
            params["officeId"] = o.officeId
            try:    
                candidates = func(**params)
                all_candidates += [[c.ballotName, c.electionOffice, c.officeStateId, c.candidateId] for c in candidates]
            except:
                pass
    else:
        try:
            candidates = func(**params)
            all_candidates += [[c.ballotName, c.electionOffice, c.officeStateId, c.candidateId] for c in candidates]
        except:
            pass
    candidatesdf = pd.DataFrame(data=all_candidates, columns=['name', 'office', 'state', 'candidateId']).drop_duplicates()
    return candidatesdf

candidate_df = get_candidates(getByZip, {"zip5":"02125", "stageId": "G"}, False)

# %%
candidate_df
# Out:
# Empty DataFrame
# Columns: [name, office, state, candidateId]
# Index: []

# %%
env = votesmart.rating.getSigList(30)
r = votesmart.rating.getCandidateRating(53279, 657)
env_col_names = [" rating text", " rating"]
col_names = [(sig.name + text).replace(" ", "_") for sig in env for text in env_col_names]
env_cols = (len(env) * 2) + 1
print(env)

# %%
envVotingId = "30"
def get_bills_year(dur):
    all_bills = []
    for year in range(2020-dur, 2021):
        try: 
            voting = votesmart.votes.getBillsByCategoryYearState(envVotingId, year, "NA")
            all_bills += [[b.billId, b.billNumber, b.title] for b in voting]
        except:
            pass
    billsdf = pd.DataFrame(data=all_bills, columns=['billId' , 'billNumber', 'billTitle'])
    return billsdf
get_bills_year(10).to_csv("votes.csv", encoding="utf-8")

# %%
votesmart.votes.getBillsByCategoryYearState(envVotingId, 2017, "NA")
# Out:
# [Bill({u'billNumber': u'PN 44', u'type': u'Nomination', u'billId': u'22559', u'title': u'Nomination of Scott Pruitt to be Administrator of the Environmental Protection Agency'}),
#  Bill({u'billNumber': u'HR 1430', u'type': u'Legislation', u'billId': u'22631', u'title': u'Honest and Open New EPA Science Treatment Act of 2017'}),
#  Bill({u'billNumber': u'HR 1431', u'type': u'Legislation', u'billId': u'22673', u'title': u'EPA Science Advisory Board Reform Act of 2017'}),
#  Bill({u'billNumber': u'HR 953', u'type': u'Legislation', u'billId': u'22858', u'title': u'Reducing Regulatory Burdens Act of 2017'}),
#  Bill({u'billNumber': u'HR 23', u'type': u'Legislation', u'billId': u'23422', u'title': u'Gaining Responsibility on Water Act'}),
#  Bill({u'billNumber': u'HR 806', u'type': u'Legislation', u'billId': u'23451', u'title': u'Ozone Standards Implementation Act of 2017'}),
#  Bill({u'billNumber': u'HR 601', u'type': u'Legislation', u'billId': u'23538', u'title': u'Continuing Appropriations Act, 2018 and Supplemental Appropriations for Disaster Relief Requirements Act, 2017'}),
#  Bill({u'billNumber': u'H Res 502', u'type': u'Legislation', u'billId': u'23539', u'title': u'Disaster Relief Appropriations Act, 2017'}),
#  Bill({u'billNumber': u'HR 2936', u'type': u'Legislation', u'billId': u'24080', u'title': u'Resilient Federal Forests Act of 2017'}),
#  Bill({u'billNumber': u'HR 2874', u'type': u'Legislation', u'billId': u'24156', u'title': u'21st Century Flood Reform Act'}),
#  Bill({u'billNumber': u'HR 4667', u'type': u'Legislation', u'billId': u'24321', u'title': u'Making further supplemental appropriations for the fiscal year ending September 30, 2018, for disaster assistance for Hurricanes Harvey, Irma, and Maria, and calendar year 2017 wildfires, and for other purposes'})]

# %%
important_bill_ids = [20653, 26353, 26930, 27188]

# %%
bill = votesmart.votes.getBill(20653)

# %%
important_bills = []
for item in important_bill_ids:
    b = votesmart.votes.getBill(item)
    important_bills += [[item, b.title, b.billNumber, b.dateIntroduced] + [[a.actionId for a in b.actions if a.stage == "Passage"]]]
billdf = pd.DataFrame(data=important_bills, columns=['bill_id', 'Title', 'Bill_Number', 'Date', 'Actions'])
billdf
# Out:
#    bill_id                                              Title Bill_Number  \
# 0    20653  A Joint Resolution Providing for Congressional...  S J Res 24
# 1    26353                             Climate Action Now Act        HR 9
# 2    26930   Arctic Cultural and Coastal Plain Protection Act     HR 1146
# 3    27188  A joint resolution providing for congressional...  S J Res 53
#
#    Date                Actions
# 0  2015  [54878, 54632, 54516]
# 1  2019                [67056]
# 2  2019                [68923]
# 3  2019                [69558]

# %%
def get_votes(row):
    votes = []
    for i, bill in enumerate(important_bill_ids):
        actions = sum(billdf.loc[billdf['bill_id'] == bill]['Actions'], [])
        bill_action = [""]
        for a in actions:
            try:
                bill_action = [votesmart.votes.getBillActionVoteByOfficial(a, row['candidateId']).action]
            except:
                pass
        votes += bill_action
    return pd.Series(votes)
vote_names = [b for b in billdf['Title'].tolist()]

# %%
def get_ratings(row):
    ratings = []
    for i, sig in enumerate(env):
        try:
            #most recent rating
            rating = votesmart.rating.getCandidateRating(row["candidateId"], sig.sigId)[-1]
            m = [rating.ratingText, rating.rating]
            ratings += m
        except:
            ratings += [""] * 2
#     ratingsdf = pd.DataFrame(data=[ratings], columns=col_names)
    return pd.Series(ratings)

# %%
def edit_name(name):
    name = re.sub(' [A-Z]. ', ' ', name)
    return name.replace(" ", "_")
    
def edit_office(office):
    if office == "President":
        return ""
    else:
        return office.split(" ")[-1]

# %%
def get_positions(row):
    URL = "https://www.ontheissues.org/%s/%s.htm" % (edit_office(row["office"]), edit_name(row["name"]))
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, 'html.parser')
    try:
        results = soup.find(id="Environment").find_next_siblings() 
        env = results[3].find("ul").text.split("\n")
        env = [e.strip() for e in env if len(e) > 0]
    except:
        env = []
    return env

# %%
candidate_df["Positions"] = candidate_df.apply(get_positions, axis=1)

# %%
candidate_df[col_names] = candidate_df.apply(get_ratings, axis=1)

# %%
candidate_df[vote_names] = candidate_df.apply(get_votes, axis=1)
candidate_df.to_csv("ma-candidate.csv", encoding="utf-8")

# %%
candidate_df.head()
# Out:
#               name       office state candidateId  \
# 0        Joe Biden    President             53279
# 2    Howie Hawkins    President              1019
# 4     Jo Jorgensen    President              2503
# 6  Donald J. Trump    President    NA       15723
# 8  Shiva Ayyadurai  U.S. Senate            185805
#
#                                            Positions  \
# 0  [Green New Deal is in platform and it's not to...
# 2  [Polluters should have burden of proof of safe...
# 4  [Companies able to pollute because government ...
# 6  [Join the United Nations' "One Trillion Trees ...
# 8  [GMOs are destroying our health; establish saf...
#
#                               350_Action_rating_text 350_Action_rating  \
# 0  Joseph Biden supported the interests of the 35...                25
# 2
# 4
# 6  President Donald Trump supported the interests...                 0
# 8
#
#    American_Forest_and_Paper_Association_rating_text  \
# 0  Joseph Biden supported the interests of the Am...
# 2
# 4
# 6
# 8
#
#   American_Forest_and_Paper_Association_rating  \
# 0                                           25
# 2
# 4
# 6
# 8
#
#                  American_Lands_Alliance_rating_text  ...  \
# 0  Joseph Biden supported the interests of the Am...  ...
# 2                                                     ...
# 4                                                     ...
# 6                                                     ...
# 8                                                     ...
#
#   Western_Organization_of_Resource_Councils_rating_text  \
# 0
# 2
# 4
# 6
# 8
#
#   Western_Organization_of_Resource_Councils_rating  \
# 0
# 2
# 4
# 6
# 8
#
#   Women's_Action_for_New_Directions_(WAND)_rating_text  \
# 0  Joseph Biden supported the interests of the Wo...
# 2
# 4
# 6
# 8
#
#   Women's_Action_for_New_Directions_(WAND)_rating Zero_Hour_rating_text  \
# 0                                              82
# 2
# 4
# 6
# 8
#
#   Zero_Hour_rating  \
# 0
# 2
# 4
# 6
# 8
#
#   A Joint Resolution Providing for Congressional Disapproval under Chapter 8 of Title 5, United States Code, of a Rule Submitted by the Environmental Protection Agency Relating to "Carbon Pollution Emission Guidelines for Existing Stationary Sources: Electric Utility Generating Units"  \
# 0
# 2
# 4
# 6
# 8
#
#   Climate Action Now Act Arctic Cultural and Coastal Plain Protection Act  \
# 0
# 2
# 4
# 6
# 8
#
#   A joint resolution providing for congressional disapproval under chapter 8 of title 5, United States Code, of the rule submitted by the Environmental Protection Agency relating to "Repeal of the Clean Power Plan; Emission Guidelines for Greenhouse Gas Emissions From Existing Electric Utility Generating Units; Revisions to Emission Guidelines Implementing Regulations"
# 0
# 2
# 4
# 6
# 8
#
# [5 rows x 91 columns]

# %%
zip_df = get_candidates(getByZip, {"zip5": "02125"}, False)
zip_df
# Out:
# [Candidate({u'electionOfficeId': u'1', u'suffix': u'Jr.', u'electionDistrictName': u'', u'runningMateId': u'120012', u'officeStateId': u'', u'electionStatus': u'Won', u'electionStage': u'Primary', u'electionDate': u'2020-03-03', u'electionDistrictId': u'', u'title': u'', u'middleName': u'Robinette', u'officeDistrictName': u'', u'officeStatus': u'', u'officeTypeId': u'', u'electionOfficeTypeId': u'P', u'officeDistrictId': u'', u'nickName': u'Joe', u'ballotName': u'Joe Biden', u'electionOffice': u'President', u'officeName': u'', u'runningMateName': u'Kamala Devi Harris', u'electionYear': u'2020', u'electionSpecial': u'f', u'preferredName': u'Joe', u'candidateId': u'53279', u'firstName': u'Joseph', u'lastName': u'Biden', u'electionParties': u'Democratic', u'officeId': u'', u'electionStateId': u'NA', u'officeParties': u''}), Candidate({u'electionOfficeId': u'1', u'suffix': u'', u'electionDistrictName': u'', u'runningMateId': u'173568', u'officeStateId': u'', u'electionStatus': u'Lost', u'electionStage': u'Primary', u'electionDate': u'2020-03-03', u'electionDistrictId': u'', u'title': u'', u'middleName': u'', u'officeDistrictName': u'', u'officeStatus': u'', u'officeTypeId': u'', u'electionOfficeTypeId': u'P', u'officeDistrictId': u'', u'nickName': u'', u'ballotName': u'Howie Hawkins', u'electionOffice': u'President', u'officeName': u'', u'runningMateName': u'Angela Nicole Walker', u'electionYear': u'2020', u'electionSpecial': u'f', u'preferredName': u'Howie', u'candidateId': u'1019', u'firstName': u'Howie', u'lastName': u'Hawkins', u'electionParties': u'Green-Rainbow', u'officeId': u'', u'electionStateId': u'NA', u'officeParties': u''}), Candidate({u'electionOfficeId': u'1', u'suffix': u'', u'electionDistrictName': u'', u'runningMateId': u'191955', u'officeStateId': u'', u'electionStatus': u'Lost', u'electionStage': u'Primary', u'electionDate': u'2020-03-03', u'electionDistrictId': u'', u'title': u'', u'middleName': u'', u'officeDistrictName': u'', u'officeStatus': u'', u'officeTypeId': u'', u'electionOfficeTypeId': u'P', u'officeDistrictId': u'', u'nickName': u'', u'ballotName': u'Jo Jorgensen', u'electionOffice': u'President', u'officeName': u'', u'runningMateName': u'Jeremy Cohen', u'electionYear': u'2020', u'electionSpecial': u'f', u'preferredName': u'Jo', u'candidateId': u'2503', u'firstName': u'Jo', u'lastName': u'Jorgensen', u'electionParties': u'Libertarian', u'officeId': u'', u'electionStateId': u'NA', u'officeParties': u''}), Candidate({u'electionOfficeId': u'1', u'suffix': u'', u'electionDistrictName': u'', u'runningMateId': u'34024', u'officeStateId': u'NA', u'electionStatus': u'Won', u'electionStage': u'Primary', u'electionDate': u'2020-03-03', u'electionDistrictId': u'', u'title': u'President', u'middleName': u'J.', u'officeDistrictName': u'', u'officeStatus': u'active', u'officeTypeId': u'P', u'electionOfficeTypeId': u'P', u'officeDistrictId': u'', u'nickName': u'', u'ballotName': u'Donald J. Trump', u'electionOffice': u'President', u'officeName': u'President', u'runningMateName': u'Mike Pence', u'electionYear': u'2020', u'electionSpecial': u'f', u'preferredName': u'Donald', u'candidateId': u'15723', u'firstName': u'Donald', u'lastName': u'Trump', u'electionParties': u'Republican', u'officeId': u'1', u'electionStateId': u'NA', u'officeParties': u'Republican'}), Candidate({u'electionOfficeId': u'6', u'suffix': u'', u'electionDistrictName': u'Jr', u'runningMateId': u'', u'officeStateId': u'', u'electionStatus': u'Lost', u'electionStage': u'Primary', u'electionDate': u'2020-09-01', u'electionDistrictId': u'20462', u'title': u'', u'middleName': u'', u'officeDistrictName': u'', u'officeStatus': u'', u'officeTypeId': u'', u'electionOfficeTypeId': u'C', u'officeDistrictId': u'', u'nickName': u'', u'ballotName': u'Shiva Ayyadurai', u'electionOffice': u'U.S. Senate', u'officeName': u'', u'runningMateName': u'', u'electionYear': u'2020', u'electionSpecial': u'f', u'preferredName': u'Shiva', u'candidateId': u'185805', u'firstN ...
# [Candidate({u'electionOfficeId': u'1', u'suffix': u'Jr.', u'electionDistrictName': u'', u'runningMateId': u'120012', u'officeStateId': u'', u'electionStatus': u'Won', u'electionStage': u'Primary', u'electionDate': u'2020-03-03', u'electionDistrictId': u'', u'title': u'', u'middleName': u'Robinette', u'officeDistrictName': u'', u'officeStatus': u'', u'officeTypeId': u'', u'electionOfficeTypeId': u'P', u'officeDistrictId': u'', u'nickName': u'Joe', u'ballotName': u'Joe Biden', u'electionOffice': u'President', u'officeName': u'', u'runningMateName': u'Kamala Devi Harris', u'electionYear': u'2020', u'electionSpecial': u'f', u'preferredName': u'Joe', u'candidateId': u'53279', u'firstName': u'Joseph', u'lastName': u'Biden', u'electionParties': u'Democratic', u'officeId': u'', u'electionStateId': u'NA', u'officeParties': u''}), Candidate({u'electionOfficeId': u'1', u'suffix': u'', u'electionDistrictName': u'', u'runningMateId': u'173568', u'officeStateId': u'', u'electionStatus': u'Lost', u'electionStage': u'Primary', u'electionDate': u'2020-03-03', u'electionDistrictId': u'', u'title': u'', u'middleName': u'', u'officeDistrictName': u'', u'officeStatus': u'', u'officeTypeId': u'', u'electionOfficeTypeId': u'P', u'officeDistrictId': u'', u'nickName': u'', u'ballotName': u'Howie Hawkins', u'electionOffice': u'President', u'officeName': u'', u'runningMateName': u'Angela Nicole Walker', u'electionYear': u'2020', u'electionSpecial': u'f', u'preferredName': u'Howie', u'candidateId': u'1019', u'firstName': u'Howie', u'lastName': u'Hawkins', u'electionParties': u'Green-Rainbow', u'officeId': u'', u'electionStateId': u'NA', u'officeParties': u''}), Candidate({u'electionOfficeId': u'1', u'suffix': u'', u'electionDistrictName': u'', u'runningMateId': u'191955', u'officeStateId': u'', u'electionStatus': u'Lost', u'electionStage': u'Primary', u'electionDate': u'2020-03-03', u'electionDistrictId': u'', u'title': u'', u'middleName': u'', u'officeDistrictName': u'', u'officeStatus': u'', u'officeTypeId': u'', u'electionOfficeTypeId': u'P', u'officeDistrictId': u'', u'nickName': u'', u'ballotName': u'Jo Jorgensen', u'electionOffice': u'President', u'officeName': u'', u'runningMateName': u'Jeremy Cohen', u'electionYear': u'2020', u'electionSpecial': u'f', u'preferredName': u'Jo', u'candidateId': u'2503', u'firstName': u'Jo', u'lastName': u'Jorgensen', u'electionParties': u'Libertarian', u'officeId': u'', u'electionStateId': u'NA', u'officeParties': u''}), Candidate({u'electionOfficeId': u'1', u'suffix': u'', u'electionDistrictName': u'', u'runningMateId': u'34024', u'officeStateId': u'NA', u'electionStatus': u'Won', u'electionStage': u'Primary', u'electionDate': u'2020-03-03', u'electionDistrictId': u'', u'title': u'President', u'middleName': u'J.', u'officeDistrictName': u'', u'officeStatus': u'active', u'officeTypeId': u'P', u'electionOfficeTypeId': u'P', u'officeDistrictId': u'', u'nickName': u'', u'ballotName': u'Donald J. Trump', u'electionOffice': u'President', u'officeName': u'President', u'runningMateName': u'Mike Pence', u'electionYear': u'2020', u'electionSpecial': u'f', u'preferredName': u'Donald', u'candidateId': u'15723', u'firstName': u'Donald', u'lastName': u'Trump', u'electionParties': u'Republican', u'officeId': u'1', u'electionStateId': u'NA', u'officeParties': u'Republican'}), Candidate({u'electionOfficeId': u'6', u'suffix': u'', u'electionDistrictName': u'Jr', u'runningMateId': u'', u'officeStateId': u'', u'electionStatus': u'Lost', u'electionStage': u'Primary', u'electionDate': u'2020-09-01', u'electionDistrictId': u'20462', u'title': u'', u'middleName': u'', u'officeDistrictName': u'', u'officeStatus': u'', u'officeTypeId': u'', u'electionOfficeTypeId': u'C', u'officeDistrictId': u'', u'nickName': u'', u'ballotName': u'Shiva Ayyadurai', u'electionOffice': u'U.S. Senate', u'officeName': u'', u'runningMateName': u'', u'electionYear': u'2020', u'electionSpecial': u'f', u'preferredName': u'Shiva', u'candidateId': u'185805', u'firstN ...
#                         name        office state candidateId
# 0                  Joe Biden     President             53279
# 1              Howie Hawkins     President              1019
# 2               Jo Jorgensen     President              2503
# 3            Donald J. Trump     President    NA       15723
# 4            Shiva Ayyadurai   U.S. Senate            185805
# 5                 Andre Gray   U.S. Senate            195211
# 6      Joseph P. Kennedy III   U.S. Senate    MA      141275
# 7                  Ed Markey   U.S. Senate    MA       26900
# 8                  Ed Markey   U.S. Senate    MA       26900
# 9           Frederick Mayock   U.S. Senate            175645
# 10         Kevin J. O'Connor   U.S. Senate            192573
# 11         Kevin J. O'Connor   U.S. Senate            192573
# 12        Ayanna S. Pressley    U.S. House    MA      122700
# 13        Ayanna S. Pressley    U.S. House    MA      122700
# 14       Robbie H. Goldstein    U.S. House            192572
# 15          Jonathan D. Lott    U.S. House            175665
# 16          Stephen F. Lynch    U.S. House    MA        4844
# 17          Stephen F. Lynch    U.S. House    MA        4844
# 18               David Biele   State House    MA      184729
# 19               Liz Miranda   State House    MA      184732
# 20  Elizabeth A. 'Liz' Malia   State House    MA        1991
# 21            Daniel J. Hunt   State House    MA      150308
# 22       Nicholas P. Collins  State Senate    MA      125266
# 23       Nicholas P. Collins  State Senate    MA      125266
# 24          Samuel H. Pierce  State Senate            194704
# 25     Sonia Rosa Chang-Díaz  State Senate    MA      109511
# 26                 Joe Biden     President             53279
# 27             Howie Hawkins     President              1019
# 28              Jo Jorgensen     President              2503
# 29           Donald J. Trump     President    NA       15723
# 30           Shiva Ayyadurai   U.S. Senate            185805
# 31                Andre Gray   U.S. Senate            195211
# 32     Joseph P. Kennedy III   U.S. Senate    MA      141275
# 33                 Ed Markey   U.S. Senate    MA       26900
# 34                 Ed Markey   U.S. Senate    MA       26900
# 35          Frederick Mayock   U.S. Senate            175645
# 36         Kevin J. O'Connor   U.S. Senate            192573
# 37         Kevin J. O'Connor   U.S. Senate            192573
# 38        Ayanna S. Pressley    U.S. House    MA      122700
# 39        Ayanna S. Pressley    U.S. House    MA      122700
# 40       Robbie H. Goldstein    U.S. House            192572
# 41          Jonathan D. Lott    U.S. House            175665
# 42          Stephen F. Lynch    U.S. House    MA        4844
# 43          Stephen F. Lynch    U.S. House    MA        4844
# 44               David Biele   State House    MA      184729
# 45               Liz Miranda   State House    MA      184732
# 46  Elizabeth A. 'Liz' Malia   State House    MA        1991
# 47            Daniel J. Hunt   State House    MA      150308
# 48       Nicholas P. Collins  State Senate    MA      125266
# 49       Nicholas P. Collins  State Senate    MA      125266
# 50          Samuel H. Pierce  State Senate            194704
# 51     Sonia Rosa Chang-Díaz  State Senate    MA      109511

# %%
def get_full_profile_zip(zip):
    df = get_candidates(getByZip, {"zip5": zip}, False)
    df[col_names] = df.apply(get_ratings, axis=1)
    df[vote_names] = df.apply(get_votes, axis=1)
    df.to_csv("sample.csv", encoding="utf-8")

# %%
get_full_profile_zip("02125")

# %%
params = dict(key=API_KEY)
r = requests.get("https://www.googleapis.com/civicinfo/v2/elections", params)
elections = r.json()["elections"]
elections
# Out:
# [{u'electionDay': u'2021-06-06',
#   u'id': u'2000',
#   u'name': u'VIP Test Election',
#   u'ocdDivisionId': u'ocd-division/country:us'},
#  {u'electionDay': u'2020-11-03',
#   u'id': u'7000',
#   u'name': u'US 2020 General Election',
#   u'ocdDivisionId': u'ocd-division/country:us'}]

# %%
print(votesmart.election.getElectionByZip("02125"))
votesmart.election.getElection("4088")
votesmart.election.getStageCandidates("4088", "G")
# votesmart.district.getByZip("02125")
# Out:
# [Election({u'name': u'2020 Massachusetts Congressional General Election', u'stateId': u'MA', u'officeTypeId': u'C', u'electionId': u'4088', u'electionYear': u'2020', u'special': u'f'}), Election({u'name': u'2020 Massachusetts Congressional Primary Election', u'stateId': u'MA', u'officeTypeId': u'C', u'electionId': u'4088', u'electionYear': u'2020', u'special': u'f'}), Election({u'name': u'2020 Massachusetts State Legislative General Election', u'stateId': u'MA', u'officeTypeId': u'L', u'electionId': u'4140', u'electionYear': u'2020', u'special': u'f'}), Election({u'name': u'2020 Massachusetts State Legislative Primary Election', u'stateId': u'MA', u'officeTypeId': u'L', u'electionId': u'4140', u'electionYear': u'2020', u'special': u'f'})]
# [Candidate({u'status': u'Running', u'candidateId': u'173832', u'votePercent': u'', u'district': u'4', u'firstName': u'Jacob', u'middleName': u'D.', u'lastName': u'Auchincloss', u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'5', u'party': u'Democratic', u'nickName': u'Jake', u'electionElectionstageId': u'7470', u'suffix': u''}),
#  Candidate({u'status': u'Running', u'candidateId': u'172879', u'votePercent': u'', u'district': u'9', u'firstName': u'Helen', u'middleName': u'', u'lastName': u'Brady', u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'5', u'party': u'Republican', u'nickName': u'', u'electionElectionstageId': u'7470', u'suffix': u''}),
#  Candidate({u'status': u'Running', u'candidateId': u'35858', u'votePercent': u'', u'district': u'5', u'firstName': u'Katherine', u'middleName': u'M.', u'lastName': u'Clark', u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'5', u'party': u'Democratic', u'nickName': u'', u'electionElectionstageId': u'7470', u'suffix': u''}),
#  Candidate({u'status': u'Running', u'candidateId': u'154071', u'votePercent': u'', u'district': u'5', u'firstName': u'Caroline', u'middleName': u'', u'lastName': u'Colarusso', u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'5', u'party': u'Republican', u'nickName': u'', u'electionElectionstageId': u'7470', u'suffix': u''}),
#  Candidate({u'status': u'Withdrawn', u'candidateId': u'195211', u'votePercent': u'', u'district': u'Jr', u'firstName': u'Andre', u'middleName': u'', u'lastName': u'Gray', u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'6', u'party': u'Green Party', u'nickName': u'', u'electionElectionstageId': u'7470', u'suffix': u''}),
#  Candidate({u'status': u'Running', u'candidateId': u'173834', u'votePercent': u'', u'district': u'4', u'firstName': u'Julie', u'middleName': u'A.', u'lastName': u'Hall', u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'5', u'party': u'Republican', u'nickName': u'', u'electionElectionstageId': u'7470', u'suffix': u''}),
#  Candidate({u'status': u'Running', u'candidateId': u'4743', u'votePercent': u'', u'district': u'9', u'firstName': u'William', u'middleName': u'R.', u'lastName': u'Keating', u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'5', u'party': u'Democratic', u'nickName': u'Bill', u'electionElectionstageId': u'7470', u'suffix': u''}),
#  Candidate({u'status': u'Running', u'candidateId': u'175665', u'votePercent': u'', u'district': u'8', u'firstName': u'Jonathan', u'middleName': u'D.', u'lastName': u'Lott', u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'5', u'party': u'Independent', u'nickName': u'', u'electionElectionstageId': u'7470', u'suffix': u''}),
#  Candidate({u'status': u'Running', u'candidateId': u'182325', u'votePercent': u'', u'district': u'2', u'firstName': u'Tracy', u'middleName': u'Lyn', u'lastName': u'Lovvorn', u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'5', u'party': u'Republican', u'nickName': u'', u'electionElectionstageId': u'7470', u'suffix': u''}),
#  Candidate({u'status': u'Running', u'candidateId': u'4844', u'votePercent': u'', u'district': u'8', u'firstName': u'Stephen', u'middleName': u'F.', u'lastName': u'Lynch', u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'5', u'party': u'Democratic', u'nickName': u'', u'electionElectionstageId': u'7470', u'suffix': u''}),
#  Candidate({u'status': u'Running', u'candidateId': u'195293', u'votePercent': u'', u'district': u'9', u'firstName': u'Michael', u'middleName': u'', u'lastName': u'Manley', u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'5', u'party': u'Independent', u'nickName': u'', u'electionElectionstageId': u'7470', u'suffix': u''}),
#  Candidate({u'status': u'Running', u'candidateId': u'26900', u'votePercent': u'', u'district': u'Jr', u'firstName': u'Edward', u'middleName': u'J.', u'lastName': u'Markey', u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'6', u'party': u'Democratic', u'nickName': u'Ed', u'electionElectionstageId': u'7470', u'suffix': u''}),
#  Candidate({u'status': u'Withdrawn', u'candidateId': u'175645', u'votePercent': u'', u'district': u'1', u'firstName': u'Frederick', u'middleName': u'O.', u'lastName': u'Mayock', u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'5', u'party': u'Independent', u'nickName': u'', u'electionElectionstageId': u'7470', u'suffix': u''}),
#  Candidate({u'status': u'Withdrawn', u'candidateId': u'175645', u'votePercent': u'', u'district': u'Jr', u'firstName': u'Frederick', u'middleName': u'O.', u'lastName': u'Mayock', u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'6', u'party': u'Independent', u'nickName': u'', u'electionElectionstageId': u'7470', u'suffix': u''}),
#  Candidate({u'status': u'Running', u'candidateId': u'552', u'votePercent': u'', u'district': u'2', u'firstName': u'James', u'middleName': u'P.', u'lastName': u'McGovern', u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'5', u'party': u'Democratic', u'nickName': u'Jim', u'electionElectionstageId': u'7470', u'suffix': u''}),
#  Candidate({u'status': u'Withdrawn', u'candidateId': u'195210', u'votePercent': u'', u'district': u'6', u'firstName': u'Matthew', u'middleName': u'', u'lastName': u'Mixon', u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'5', u'party': u'Independent', u'nickName': u'', u'electionElectionstageId': u'7470', u'suffix': u''}),
#  Candidate({u'status': u'Running', u'candidateId': u'192574', u'votePercent': u'', u'district': u'6', u'firstName': u'John', u'middleName': u'Paul', u'lastName': u'Moran', u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'5', u'party': u'Republican', u'nickName': u'', u'electionElectionstageId': u'7470', u'suffix': u''}),
#  Candidate({u'status': u'Running', u'candidateId': u'146299', u'votePercent': u'', u'district': u'6', u'firstName': u'Seth', u'middleName': u'W.', u'lastName': u'Moulton', u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'5', u'party': u'Democratic', u'nickName': u'', u'electionElectionstageId': u'7470', u'suffix': u''}),
#  Candidate({u'status': u'Running', u'candidateId': u'26895', u'votePercent': u'', u'district': u'1', u'firstName': u'Richard', u'middleName': u'Edmund', u'lastName': u'Neal', u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'5', u'party': u'Democratic', u'nickName': u'', u'electionElectionstageId': u'7470', u'suffix': u''}),
#  Candidate({u'status': u'Running', u'candidateId': u'192573', u'votePercent': u'', u'district': u'Jr', u'firstName': u'Kevin', u'middleName': u'J.', u'lastName': u"O'Connor", u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'6', u'party': u'Republican', u'nickName': u'', u'electionElectionstageId': u'7470', u'suffix': u''}),
#  Candidate({u'status': u'Running', u'candidateId': u'35701', u'votePercent': u'', u'district': u'7', u'firstName': u'Roy', u'middleName': u'', u'lastName': u'Owens', u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'5', u'party': u'Independent', u'nickName': u'', u'electionElectionstageId': u'7470', u'suffix': u''}),
#  Candidate({u'status': u'Running', u'candidateId': u'122700', u'votePercent': u'', u'district': u'7', u'firstName': u'Ayanna', u'middleName': u'S.', u'lastName': u'Pressley', u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'5', u'party': u'Democratic', u'nickName': u'', u'electionElectionstageId': u'7470', u'suffix': u''}),
#  Candidate({u'status': u'Running', u'candidateId': u'182310', u'votePercent': u'', u'district': u'3', u'firstName': u'Lori', u'middleName': u'Loureiro', u'lastName': u'Trahan', u'runningMateName': u'', u'voteCount': u'', u'runningMateId': u'', u'officeId': u'5', u'party': u'Democratic', u'nickName': u'', u'electionElectionstageId': u'7470', u'suffix': u''})]

# %%
def create_candidate_profile(c):
    try:
        df = candidate_df.loc[candidate_df['candidateId'] == c.candidateId].to_dict("records")[0]
        df = OrderedDict([(k, df[k]) for k in candidate_df.columns.to_list()])
        return df
    except:
        name = "%s %s" % (c.firstName, c.lastName)
        return {"name": name}

# %%
def get_election_data(zipcode):
    json_data = OrderedDict({"zip": zipcode, "elections": []})
#     elections = requests.get("https://www.googleapis.com/civicinfo/v2/elections", params).json()["elections"]
    elections = votesmart.election.getElectionByZip(zipcode)
    for election in elections:
        if election.officeTypeId == "C":
            candidates = votesmart.election.getStageCandidates(election.electionId, "G")
            electionInfo = votesmart.election.getElection(election.electionId)
            date = electionInfo.stages[-1].electionDate
            election_data = OrderedDict([("name", election.name), 
                             ("date", date),
                             ("candidates", [])])
            election_data["candidates"] = [create_candidate_profile(c) for c in candidates if c.status == "Running"]
            json_data["elections"].append(election_data)
    with open('sample.json', 'w') as f:
        json.dump(json_data, f)
    return json_data
    
get_election_data("02125")
# Out:
# OrderedDict([('elections',
#               [OrderedDict([('name',
#                              u'2020 Massachusetts Congressional General Election'),
#                             ('date', u'2020-11-03'),
#                             ('candidates',
#                              [{'name': u'Jacob Auchincloss'},
#                               {'name': u'Helen Brady'},
#                               {'name': u'Katherine Clark'},
#                               {'name': u'Caroline Colarusso'},
#                               {'name': u'Julie Hall'},
#                               {'name': u'William Keating'},
#                               OrderedDict([('name', u'Jonathan D. Lott'),
#                                            ('office', u'U.S. House'),
#                                            ('state', u''),
#                                            ('candidateId', u'175665'),
#                                            ('Positions', []),
#                                            (u'350_Action_rating_text', ''),
#                                            (u'350_Action_rating', ''),
#                                            (u'American_Forest_and_Paper_Association_rating_text',
#                                             ''),
#                                            (u'American_Forest_and_Paper_Association_rating',
#                                             ''),
#                                            (u'American_Lands_Alliance_rating_text',
#                                             ''),
#                                            (u'American_Lands_Alliance_rating',
#                                             ''),
#                                            (u'American_Society_of_Landscape_Architects_rating_text',
#                                             ''),
#                                            (u'American_Society_of_Landscape_Architects_rating',
#                                             ''),
#                                            (u'American_Wilderness_Coalition_rating_text',
#                                             ''),
#                                            (u'American_Wilderness_Coalition_rating',
#                                             ''),
#                                            (u'Associated_Equipment_Distributors_rating_text',
#                                             ''),
#                                            (u'Associated_Equipment_Distributors_rating',
#                                             ''),
#                                            (u'Brand_New_Congress_rating_text',
#                                             ''),
#                                            (u'Brand_New_Congress_rating', ''),
#                                            (u'Californians_for_Population_Stabilization_rating_text',
#                                             ''),
#                                            (u'Californians_for_Population_Stabilization_rating',
#                                             ''),
#                                            (u'Center_For_Biological_Diversity_Action_Fund_rating_text',
#                                             ''),
#                                            (u'Center_For_Biological_Diversity_Action_Fund_rating',
#                                             ''),
#                                            (u'Center_for_International_Policy_rating_text',
#                                             ''),
#                                            (u'Center_for_International_Policy_rating',
#                                             ''),
#                                            (u'Citizens_for_Global_Solutions_rating_text',
#                                             ''),
#                                            (u'Citizens_for_Global_Solutions_rating',
#                                             ''),
#                                            (u'Clean_Water_Action_rating_text',
#                                             ''),
#                                            (u'Clean_Water_Action_rating', ''),
#                                            (u'Climate_Hawks_Vote_rating_text',
#                                             ''),
#                                            (u'Climate_Hawks_Vote_rating', ''),
#                                            (u'Common_Defense_rating_text', ''),
#                                            (u'Common_Defense_rating', ''),
#                                            (u'Competitive_Enterprise_Institute_rating_text',
#                                             ''),
#                                            (u'Competitive_Enterprise_Institute_rating',
#                                             ''),
#                                            (u'ConservAmerica_rating_text', ''),
#                                            (u'ConservAmerica_rating', ''),
#                                            (u'Defenders_of_Wildlife_Action_Fund_rating_text',
#                                             ''),
#                                            (u'Defenders_of_Wildlife_Action_Fund_rating',
#                                             ''),
#                                            (u'Democratic_Socialists_Of_America_rating_text',
#                                             ''),
#                                            (u'Democratic_Socialists_Of_America_rating',
#                                             ''),
#                                            (u'EarthRights_International_rating_text',
#                                             ''),
#                                            (u'EarthRights_International_rating',
#                                             ''),
#                                            (u'Environment_America_rating_text',
#                                             ''),
#                                            (u'Environment_America_rating', ''),
#                                            (u'Food_Policy_Action_rating_text',
#                                             ''),
#                                            (u'Food_Policy_Action_rating', ''),
#                                            (u'Friends_of_the_Earth_Action_rating_text',
#                                             ''),
#                                            (u'Friends_of_the_Earth_Action_rating',
#                                             ''),
#                                            (u'Future_Now_Fund_rating_text',
#                                             ''),
#                                            (u'Future_Now_Fund_rating', ''),
#                                            (u'Global_Exchange_rating_text',
#                                             ''),
#                                            (u'Global_Exchange_rating', ''),
#                                            (u'Greenpeace_rating_text', ''),
#                                            (u'Greenpeace_rating', ''),
#                                            (u'League_of_Conservation_Voters_rating_text',
#                                             ''),
#                                            (u'League_of_Conservation_Voters_rating',
#                                             ''),
#                                            (u'Matriarch_rating_text', ''),
#                                            (u'Matriarch_rating', ''),
#                                            (u'National_Parks_Conservation_Association_rating_text',
#                                             ''),
#                                            (u'National_Parks_Conservation_Association_rating',
#                                             ''),
#                                            (u'NextGen_America_rating_text',
#                                             ''),
#                                            (u'NextGen_America_rating', ''),
#                                            (u'Ocean_Champions_rating_text',
#                                             ''),
#                                            (u'Ocean_Champions_rating', ''),
#                                            (u'Outdoor_Industry_Association_Political_Action_Committee_rating_text',
#                                             ''),
#                                            (u'Outdoor_Industry_Association_Political_Action_Committee_rating',
#                                             ''),
#                                            (u'Partnership_for_America_rating_text',
#                                             ''),
#                                            (u'Partnership_for_America_rating',
#                                             ''),
#                                            (u"Rachel's_Action_Network_rating_text",
#                                             ''),
#                                            (u"Rachel's_Action_Network_rating",
#                                             ''),
#                                            (u'Sierra_Club_rating_text', ''),
#                                            (u'Sierra_Club_rating', ''),
#                                            (u'Southern_Alliance_for_Clean_Energy_Action_Fund_rating_text',
#                                             ''),
#                                            (u'Southern_Alliance_for_Clean_Energy_Action_Fund_rating',
#                                             ''),
#                                            (u'Sunrise_Movement_rating_text',
#                                             ''),
#                                            (u'Sunrise_Movement_rating', ''),
#                                            (u'The_Climate_Mobilization_rating_text',
#                                             ''),
#                                            (u'The_Climate_Mobilization_rating',
#                                             ''),
#                                            (u'The_National_Wildlife_Federation_Action_Fund_rating_text',
#                                             ''),
#                                            (u'The_National_Wildlife_Federation_Action_Fund_rating',
#                                             ''),
#                                            (u'Western_Organization_of_Resource_Councils_rating_text',
#                                             ''),
#                                            (u'Western_Organization_of_Resource_Councils_rating',
#                                             ''),
#                                            (u"Women's_Action_for_New_Directions_(WAND)_rating_text",
#                                             ''),
#                                            (u"Women's_Action_for_New_Directions_(WAND)_rating",
#                                             ''),
#                                            (u'Zero_Hour_rating_text', ''),
#                                            (u'Zero_Hour_rating', ''),
#                                            (u'A Joint Resolution Providing for Congressional Disapproval under Chapter 8 of Title 5, United States Code, of a Rule Submitted by the Environmental Protection Agency Relating to "Carbon Pollution Emission Guidelines for Existing Stationary Sources: Electric Utility Generating Units"',
#                                             ''),
#                                            (u'Climate Action Now Act', ''),
#                                            (u'Arctic Cultural and Coastal Plain Protection Act',
#                                             ''),
#                                            (u'A joint resolution providing for congressional disapproval under chapter 8 of title 5, United States Code, of the rule submitted by the Environmental Protection Agency relating to "Repeal of the Clean Power Plan; Emission Guidelines for Greenhouse Gas Emissions From Existing Electric Utility Generating Units; Revisions to Emission Guidelines Implementing Regulations"',
#                                             '')]),
#                               {'name': u'Tracy Lovvorn'},
#                               OrderedDict([('name', u'Stephen F. Lynch'),
#                                            ('office', u'U.S. House'),
#                                            ('state', u'MA'),
#                                            ('candidateId', u'4844'),
#                                            ('Positions', []),
#                                            (u'350_Action_rating_text', ''),
#                                            (u'350_Action_rating', ''),
#                                            (u'American_Forest_and_Paper_Association_rating_text',
#                                             u'Representative Stephen Lynch supported the interests of the American Forest and Paper Association 16 percent in 2003-2004.'),
#                                            (u'American_Forest_and_Paper_Association_rating',
#                                             u'16'),
#                                            (u'American_Lands_Alliance_rating_text',
#                                             u'Representative Stephen Lynch supported the interests of the American Lands Alliance 100 percent in 2003.'),
#                                            (u'American_Lands_Alliance_rating',
#                                             u'100'),
#                                            (u'American_Society_of_Landscape_Architects_rating_text',
#                                             u'In 2007 American Society of Landscape Architects gave Representative Stephen Lynch a rating of 100.'),
#                                            (u'American_Society_of_Landscape_Architects_rating',
#                                             u'100'),
#                                            (u'American_Wilderness_Coalition_rating_text',
#                                             u'Representative Stephen Lynch supported the interests of the American Wilderness Coalition 100 percent in 2003-2004.'),
#                                            (u'American_Wilderness_Coalition_rating',
#                                             u'100'),
#                                            (u'Associated_Equipment_Distributors_rating_text',
#                                             u'Representative Stephen Lynch supported the interests of the Associated Equipment Distributors 85 percent in 2007.'),
#                                            (u'Associated_Equipment_Distributors_rating',
#                                             u'85'),
#                                            (u'Brand_New_Congress_rating_text',
#                                             ''),
#                                            (u'Brand_New_Congress_rating', ''),
#                                            (u'Californians_for_Population_Stabilization_rating_text',
#                                             u'Representative Stephen Lynch supported the interests of the Californians for Population Stabilization 33 percent in 2002.'),
#                                            (u'Californians_for_Population_Stabilization_rating',
#                                             u'33'),
#                                            (u'Center_For_Biological_Diversity_Action_Fund_rating_text',
#                                             u'Representative Stephen Lynch supported the interests of the Center For Biological Diversity Action Fund 85 percent in 2018.'),
#                                            (u'Center_For_Biological_Diversity_Action_Fund_rating',
#                                             u'85'),
#                                            (u'Center_for_International_Policy_rating_text',
#                                             u'Representative Stephen Lynch supported the interests of the Center for International Policy 100 percent in 2004.'),
#                                            (u'Center_for_International_Policy_rating',
#                                             u'100'),
#                                            (u'Citizens_for_Global_Solutions_rating_text',
#                                             u'Representative Stephen Lynch supported the interests of the Citizens for Global Solutions 60 percent in 2002-2003.'),
#                                            (u'Citizens_for_Global_Solutions_rating',
#                                             u'60'),
#                                            (u'Clean_Water_Action_rating_text',
#                                             u'Representative Stephen Lynch supported the interests of the Clean Water Action 100 percent in 2011-2012.'),
#                                            (u'Clean_Water_Action_rating',
#                                             u'100'),
#                                            (u'Climate_Hawks_Vote_rating_text',
#                                             ''),
#                                            (u'Climate_Hawks_Vote_rating', ''),
#                                            (u'Common_Defense_rating_text', ''),
#                                            (u'Common_Defense_rating', ''),
#                                            (u'Competitive_Enterprise_Institute_rating_text',
#                                             u''),
#                                            (u'Competitive_Enterprise_Institute_rating',
#                                             u'0'),
#                                            (u'ConservAmerica_rating_text', ''),
#                                            (u'ConservAmerica_rating', ''),
#                                            (u'Defenders_of_Wildlife_Action_Fund_rating_text',
#                                             u'Representative Stephen Lynch supported the interests of the Defenders of Wildlife Action Fund 100 percent in 2003.'),
#                                            (u'Defenders_of_Wildlife_Action_Fund_rating',
#                                             u'100'),
#                                            (u'Democratic_Socialists_Of_America_rating_text',
#                                             ''),
#                                            (u'Democratic_Socialists_Of_America_rating',
#                                             ''),
#                                            (u'EarthRights_International_rating_text',
#                                             u'Representative Stephen Lynch supported the interests of the EarthRights International 44 percent in 2012.'),
#                                            (u'EarthRights_International_rating',
#                                             u'44'),
#                                            (u'Environment_America_rating_text',
#                                             u'Representative Stephen Lynch supported the interests of the Environment America 100 percent in 2008.'),
#                                            (u'Environment_America_rating',
#                                             u'100'),
#                                            (u'Food_Policy_Action_rating_text',
#                                             u"Based on a point system, with points assigned for actions in support of or in opposition to Food Policy Action's position, Representative Stephen Lynch received a rating of 100."),
#                                            (u'Food_Policy_Action_rating',
#                                             u'100'),
#                                            (u'Friends_of_the_Earth_Action_rating_text',
#                                             ''),
#                                            (u'Friends_of_the_Earth_Action_rating',
#                                             ''),
#                                            (u'Future_Now_Fund_rating_text',
#                                             ''),
#                                            (u'Future_Now_Fund_rating', ''),
#                                            (u'Global_Exchange_rating_text',
#                                             u''),
#                                            (u'Global_Exchange_rating', u'14'),
#                                            (u'Greenpeace_rating_text', ''),
#                                            (u'Greenpeace_rating', ''),
#                                            (u'League_of_Conservation_Voters_rating_text',
#                                             u'Representative Stephen Lynch supported the interests of the League of Conservation Voters 100 percent in 2001-2002.'),
#                                            (u'League_of_Conservation_Voters_rating',
#                                             u'100'),
#                                            (u'Matriarch_rating_text', ''),
#                                            (u'Matriarch_rating', ''),
#                                            (u'National_Parks_Conservation_Association_rating_text',
#                                             u'Representative Stephen Lynch supported the interests of the National Parks Conservation Association 100 percent in 2003-2004.'),
#                                            (u'National_Parks_Conservation_Association_rating',
#                                             u'100'),
#                                            (u'NextGen_America_rating_text',
#                                             ''),
#                                            (u'NextGen_America_rating', ''),
#                                            (u'Ocean_Champions_rating_text',
#                                             ''),
#                                            (u'Ocean_Champions_rating', ''),
#                                            (u'Outdoor_Industry_Association_Political_Action_Committee_rating_text',
#                                             u'Representative Stephen Lynch supported the interests of the Outdoor Industry Association Political Action Committee 100 percent in 2017-2018.'),
#                                            (u'Outdoor_Industry_Association_Political_Action_Committee_rating',
#                                             u'100'),
#                                            (u'Partnership_for_America_rating_text',
#                                             u'Representative Stephen Lynch supported the interests of the Partnership for America 6 percent in 2005-2006.'),
#                                            (u'Partnership_for_America_rating',
#                                             u'6'),
#                                            (u"Rachel's_Action_Network_rating_text",
#                                             ''),
#                                            (u"Rachel's_Action_Network_rating",
#                                             ''),
#                                            (u'Sierra_Club_rating_text',
#                                             u'Representative Stephen Lynch supported the interests of the Sierra Club 100 percent in 2003.'),
#                                            (u'Sierra_Club_rating', u'100'),
#                                            (u'Southern_Alliance_for_Clean_Energy_Action_Fund_rating_text',
#                                             ''),
#                                            (u'Southern_Alliance_for_Clean_Energy_Action_Fund_rating',
#                                             ''),
#                                            (u'Sunrise_Movement_rating_text',
#                                             ''),
#                                            (u'Sunrise_Movement_rating', ''),
#                                            (u'The_Climate_Mobilization_rating_text',
#                                             ''),
#                                            (u'The_Climate_Mobilization_rating',
#                                             ''),
#                                            (u'The_National_Wildlife_Federation_Action_Fund_rating_text',
#                                             ''),
#                                            (u'The_National_Wildlife_Federation_Action_Fund_rating',
#                                             ''),
#                                            (u'Western_Organization_of_Resource_Councils_rating_text',
#                                             ''),
#                                            (u'Western_Organization_of_Resource_Councils_rating',
#                                             ''),
#                                            (u"Women's_Action_for_New_Directions_(WAND)_rating_text",
#                                             u"Representative Stephen Lynch supported the interests of the Women's Action for New Directions (WAND) 67 percent in 2001-2002."),
#                                            (u"Women's_Action_for_New_Directions_(WAND)_rating",
#                                             u'67'),
#                                            (u'Zero_Hour_rating_text', ''),
#                                            (u'Zero_Hour_rating', ''),
#                                            (u'A Joint Resolution Providing for Congressional Disapproval under Chapter 8 of Title 5, United States Code, of a Rule Submitted by the Environmental Protection Agency Relating to "Carbon Pollution Emission Guidelines for Existing Stationary Sources: Electric Utility Generating Units"',
#                                             u'Nay'),
#                                            (u'Climate Action Now Act', u'Yea'),
#                                            (u'Arctic Cultural and Coastal Plain Protection Act',
#                                             u'Yea'),
#                                            (u'A joint resolution providing for congressional disapproval under chapter 8 of title 5, United States Code, of the rule submitted by the Environmental Protection Agency relating to "Repeal of the Clean Power Plan; Emission Guidelines for Greenhouse Gas Emissions From Existing Electric Utility Generating Units; Revisions to Emission Guidelines Implementing Regulations"',
#                                             '')]),
#                               {'name': u'Michael Manley'},
#                               OrderedDict([('name', u'Ed Markey'),
#                                            ('office', u'U.S. Senate'),
#                                            ('state', u'MA'),
#                                            ('candidateId', u'26900'),
#                                            ('Positions',
#                                             [u'Nuclear power is a very expensive way to boil water. (Nov 2019)',
#                                              u'Voted YES on $2 billion more for Cash for Clunkers program. (Jul 2009)',
#                                              u'Voted YES on protecting free-roaming horses and burros. (Jul 2009)',
#                                              u'Voted YES on environmental education grants for outdoor experiences. (Sep 2008)',
#                                              u'Voted YES on $9.7B for Amtrak improvements and operation thru 2013. (Jun 2008)',
#                                              u'Voted YES on increasing AMTRAK funding by adding $214M to $900M. (Jun 2006)',
#                                              u'Voted YES on barring website promoting Yucca Mountain nuclear waste dump. (May 2006)',
#                                              u'Voted NO on deauthorizing "critical habitat" for endangered species. (Sep 2005)',
#                                              u'Voted NO on speeding up approval of forest thinning projects. (Nov 2003)',
#                                              u'Prohibits commercial logging on Federal public lands. (Apr 2001)',
#                                              u'Rated 100% by the LCV, indicating pro-environment votes. (Dec 2003)',
#                                              u'Regulate all dog breeders down to kennels of 50 dogs. (Feb 2011)',
#                                              u'Leader of House Natural Resources Committee. (Mar 2011)',
#                                              u'Prohibits breeding or possessing Big Cat species. (Apr 2012)',
#                                              u'Rated 100% by HSLF, indicating a pro-animal welfare voting record. (Jan 2012)',
#                                              u'Sponsored enforcing against illegal ocean fishing. (Jan 2013)',
#                                              u'Endorsed Endorsed by LCV; supports conservation efforts. (Aug 2014)',
#                                              u'Strengthen prohibitions against animal fighting. (Jan 2007)']),
#                                            (u'350_Action_rating_text', ''),
#                                            (u'350_Action_rating', ''),
#                                            (u'American_Forest_and_Paper_Association_rating_text',
#                                             u'Senator Edward Markey supported the interests of the American Forest and Paper Association 8 percent in 2003-2004.'),
#                                            (u'American_Forest_and_Paper_Association_rating',
#                                             u'8'),
#                                            (u'American_Lands_Alliance_rating_text',
#                                             u'Senator Edward Markey supported the interests of the American Lands Alliance 100 percent in 1999-2000.'),
#                                            (u'American_Lands_Alliance_rating',
#                                             u'100'),
#                                            (u'American_Society_of_Landscape_Architects_rating_text',
#                                             u'In 2007 American Society of Landscape Architects gave Senator Edward Markey a rating of 100.'),
#                                            (u'American_Society_of_Landscape_Architects_rating',
#                                             u'100'),
#                                            (u'American_Wilderness_Coalition_rating_text',
#                                             u'Senator Edward Markey supported the interests of the American Wilderness Coalition 100 percent in 2001-2002.'),
#                                            (u'American_Wilderness_Coalition_rating',
#                                             u'100'),
#                                            (u'Associated_Equipment_Distributors_rating_text',
#                                             u'Senator Edward Markey supported the interests of the Associated Equipment Distributors 85 percent in 2007.'),
#                                            (u'Associated_Equipment_Distributors_rating',
#                                             u'85'),
#                                            (u'Brand_New_Congress_rating_text',
#                                             ''),
#                                            (u'Brand_New_Congress_rating', ''),
#                                            (u'Californians_for_Population_Stabilization_rating_text',
#                                             u'Senator Edward Markey supported the interests of the Californians for Population Stabilization 50 percent in 2001.'),
#                                            (u'Californians_for_Population_Stabilization_rating',
#                                             u'50'),
#                                            (u'Center_For_Biological_Diversity_Action_Fund_rating_text',
#                                             u'Senator Edward Markey supported the interests of the Center For Biological Diversity Action Fund 100 percent in 2018.'),
#                                            (u'Center_For_Biological_Diversity_Action_Fund_rating',
#                                             u'100'),
#                                            (u'Center_for_International_Policy_rating_text',
#                                             u'Senator Edward Markey supported the interests of the Center for International Policy 100 percent in 2004.'),
#                                            (u'Center_for_International_Policy_rating',
#                                             u'100'),
#                                            (u'Citizens_for_Global_Solutions_rating_text',
#                                             u'Senator Edward Markey supported the interests of the Citizens for Global Solutions 92 percent in 2002-2003.'),
#                                            (u'Citizens_for_Global_Solutions_rating',
#                                             u'92'),
#                                            (u'Clean_Water_Action_rating_text',
#                                             u'Senator Edward Markey supported the interests of the Clean Water Action 100 percent in 2011-2012.'),
#                                            (u'Clean_Water_Action_rating',
#                                             u'100'),
#                                            (u'Climate_Hawks_Vote_rating_text',
#                                             u'Senator Edward Markey supported the interests of the Climate Hawks Vote 94 percent in 2013-2014.'),
#                                            (u'Climate_Hawks_Vote_rating',
#                                             u'94'),
#                                            (u'Common_Defense_rating_text', ''),
#                                            (u'Common_Defense_rating', ''),
#                                            (u'Competitive_Enterprise_Institute_rating_text',
#                                             u'Senator Edward Markey supported the interests of the Competitive Enterprise Institute 0 percent in 1994.'),
#                                            (u'Competitive_Enterprise_Institute_rating',
#                                             u'0'),
#                                            (u'ConservAmerica_rating_text', ''),
#                                            (u'ConservAmerica_rating', ''),
#                                            (u'Defenders_of_Wildlife_Action_Fund_rating_text',
#                                             u'Senator Edward Markey supported the interests of the Defenders of Wildlife Action Fund 100 percent in 2003.'),
#                                            (u'Defenders_of_Wildlife_Action_Fund_rating',
#                                             u'100'),
#                                            (u'Democratic_Socialists_Of_America_rating_text',
#                                             ''),
#                                            (u'Democratic_Socialists_Of_America_rating',
#                                             ''),
#                                            (u'EarthRights_International_rating_text',
#                                             u'Senator Edward Markey supported the interests of the EarthRights International 44 percent in 2012.'),
#                                            (u'EarthRights_International_rating',
#                                             u'44'),
#                                            (u'Environment_America_rating_text',
#                                             u'Senator Edward Markey supported the interests of the Environment America 100 percent in 2008.'),
#                                            (u'Environment_America_rating',
#                                             u'100'),
#                                            (u'Food_Policy_Action_rating_text',
#                                             u"Based on a point system, with points assigned for actions in support of or in opposition to Food Policy Action's position, Senator Edward Markey received a rating of 92."),
#                                            (u'Food_Policy_Action_rating',
#                                             u'92'),
#                                            (u'Friends_of_the_Earth_Action_rating_text',
#                                             ''),
#                                            (u'Friends_of_the_Earth_Action_rating',
#                                             ''),
#                                            (u'Future_Now_Fund_rating_text',
#                                             ''),
#                                            (u'Future_Now_Fund_rating', ''),
#                                            (u'Global_Exchange_rating_text',
#                                             u''),
#                                            (u'Global_Exchange_rating', u'14'),
#                                            (u'Greenpeace_rating_text', ''),
#                                            (u'Greenpeace_rating', ''),
#                                            (u'League_of_Conservation_Voters_rating_text',
#                                             u'On the votes that the League of Conservation Voters considered to be the most important in 1995-1996 , Senator Edward Markey voted their preferred position 96 percent of the time.'),
#                                            (u'League_of_Conservation_Voters_rating',
#                                             u'96'),
#                                            (u'Matriarch_rating_text', ''),
#                                            (u'Matriarch_rating', ''),
#                                            (u'National_Parks_Conservation_Association_rating_text',
#                                             u'Senator Edward Markey supported the interests of the National Parks Conservation Association 87 percent in 1999-2000.'),
#                                            (u'National_Parks_Conservation_Association_rating',
#                                             u'87'),
#                                            (u'NextGen_America_rating_text',
#                                             ''),
#                                            (u'NextGen_America_rating', ''),
#                                            (u'Ocean_Champions_rating_text',
#                                             ''),
#                                            (u'Ocean_Champions_rating', ''),
#                                            (u'Outdoor_Industry_Association_Political_Action_Committee_rating_text',
#                                             u'Senator Edward Markey supported the interests of the Outdoor Industry Association Political Action Committee 75 percent in 2017-2018.'),
#                                            (u'Outdoor_Industry_Association_Political_Action_Committee_rating',
#                                             u'75'),
#                                            (u'Partnership_for_America_rating_text',
#                                             u'Senator Edward Markey supported the interests of the Partnership for America 0 percent in 2005-2006.'),
#                                            (u'Partnership_for_America_rating',
#                                             u'0'),
#                                            (u"Rachel's_Action_Network_rating_text",
#                                             ''),
#                                            (u"Rachel's_Action_Network_rating",
#                                             ''),
#                                            (u'Sierra_Club_rating_text',
#                                             u'Senator Edward Markey supported the interests of the Sierra Club 100 percent in 2003.'),
#                                            (u'Sierra_Club_rating', u'100'),
#                                            (u'Southern_Alliance_for_Clean_Energy_Action_Fund_rating_text',
#                                             ''),
#                                            (u'Southern_Alliance_for_Clean_Energy_Action_Fund_rating',
#                                             ''),
#                                            (u'Sunrise_Movement_rating_text',
#                                             ''),
#                                            (u'Sunrise_Movement_rating', ''),
#                                            (u'The_Climate_Mobilization_rating_text',
#                                             ''),
#                                            (u'The_Climate_Mobilization_rating',
#                                             ''),
#                                            (u'The_National_Wildlife_Federation_Action_Fund_rating_text',
#                                             ''),
#                                            (u'The_National_Wildlife_Federation_Action_Fund_rating',
#                                             ''),
#                                            (u'Western_Organization_of_Resource_Councils_rating_text',
#                                             ''),
#                                            (u'Western_Organization_of_Resource_Councils_rating',
#                                             ''),
#                                            (u"Women's_Action_for_New_Directions_(WAND)_rating_text",
#                                             u"Senator Edward Markey supported the interests of the Women's Action for New Directions (WAND) 89 percent in 2001-2002."),
#                                            (u"Women's_Action_for_New_Directions_(WAND)_rating",
#                                             u'89'),
#                                            (u'Zero_Hour_rating_text', ''),
#                                            (u'Zero_Hour_rating', ''),
#                                            (u'A Joint Resolution Providing for Congressional Disapproval under Chapter 8 of Title 5, United States Code, of a Rule Submitted by the Environmental Protection Agency Relating to "Carbon Pollution Emission Guidelines for Existing Stationary Sources: Electric Utility Generating Units"',
#                                             u'Nay'),
#                                            (u'Climate Action Now Act', ''),
#                                            (u'Arctic Cultural and Coastal Plain Protection Act',
#                                             ''),
#                                            (u'A joint resolution providing for congressional disapproval under chapter 8 of title 5, United States Code, of the rule submitted by the Environmental Protection Agency relating to "Repeal of the Clean Power Plan; Emission Guidelines for Greenhouse Gas Emissions From Existing Electric Utility Generating Units; Revisions to Emission Guidelines Implementing Regulations"',
#                                             u'Yea')]),
#                               {'name': u'James McGovern'},
#                               {'name': u'John Moran'},
#                               {'name': u'Seth Moulton'},
#                               {'name': u'Richard Neal'},
#                               OrderedDict([('name', u"Kevin J. O'Connor"),
#                                            ('office', u'U.S. Senate'),
#                                            ('state', u''),
#                                            ('candidateId', u'192573'),
#                                            ('Positions', []),
#                                            (u'350_Action_rating_text', ''),
#                                            (u'350_Action_rating', ''),
#                                            (u'American_Forest_and_Paper_Association_rating_text',
#                                             ''),
#                                            (u'American_Forest_and_Paper_Association_rating',
#                                             ''),
#                                            (u'American_Lands_Alliance_rating_text',
#                                             ''),
#                                            (u'American_Lands_Alliance_rating',
#                                             ''),
#                                            (u'American_Society_of_Landscape_Architects_rating_text',
#                                             ''),
#                                            (u'American_Society_of_Landscape_Architects_rating',
#                                             ''),
#                                            (u'American_Wilderness_Coalition_rating_text',
#                                             ''),
#                                            (u'American_Wilderness_Coalition_rating',
#                                             ''),
#                                            (u'Associated_Equipment_Distributors_rating_text',
#                                             ''),
#                                            (u'Associated_Equipment_Distributors_rating',
#                                             ''),
#                                            (u'Brand_New_Congress_rating_text',
#                                             ''),
#                                            (u'Brand_New_Congress_rating', ''),
#                                            (u'Californians_for_Population_Stabilization_rating_text',
#                                             ''),
#                                            (u'Californians_for_Population_Stabilization_rating',
#                                             ''),
#                                            (u'Center_For_Biological_Diversity_Action_Fund_rating_text',
#                                             ''),
#                                            (u'Center_For_Biological_Diversity_Action_Fund_rating',
#                                             ''),
#                                            (u'Center_for_International_Policy_rating_text',
#                                             ''),
#                                            (u'Center_for_International_Policy_rating',
#                                             ''),
#                                            (u'Citizens_for_Global_Solutions_rating_text',
#                                             ''),
#                                            (u'Citizens_for_Global_Solutions_rating',
#                                             ''),
#                                            (u'Clean_Water_Action_rating_text',
#                                             ''),
#                                            (u'Clean_Water_Action_rating', ''),
#                                            (u'Climate_Hawks_Vote_rating_text',
#                                             ''),
#                                            (u'Climate_Hawks_Vote_rating', ''),
#                                            (u'Common_Defense_rating_text', ''),
#                                            (u'Common_Defense_rating', ''),
#                                            (u'Competitive_Enterprise_Institute_rating_text',
#                                             ''),
#                                            (u'Competitive_Enterprise_Institute_rating',
#                                             ''),
#                                            (u'ConservAmerica_rating_text', ''),
#                                            (u'ConservAmerica_rating', ''),
#                                            (u'Defenders_of_Wildlife_Action_Fund_rating_text',
#                                             ''),
#                                            (u'Defenders_of_Wildlife_Action_Fund_rating',
#                                             ''),
#                                            (u'Democratic_Socialists_Of_America_rating_text',
#                                             ''),
#                                            (u'Democratic_Socialists_Of_America_rating',
#                                             ''),
#                                            (u'EarthRights_International_rating_text',
#                                             ''),
#                                            (u'EarthRights_International_rating',
#                                             ''),
#                                            (u'Environment_America_rating_text',
#                                             ''),
#                                            (u'Environment_America_rating', ''),
#                                            (u'Food_Policy_Action_rating_text',
#                                             ''),
#                                            (u'Food_Policy_Action_rating', ''),
#                                            (u'Friends_of_the_Earth_Action_rating_text',
#                                             ''),
# ...
#                                             ''),
#                                            (u'National_Parks_Conservation_Association_rating',
#                                             ''),
#                                            (u'NextGen_America_rating_text',
#                                             ''),
#                                            (u'NextGen_America_rating', ''),
#                                            (u'Ocean_Champions_rating_text',
#                                             ''),
#                                            (u'Ocean_Champions_rating', ''),
#                                            (u'Outdoor_Industry_Association_Political_Action_Committee_rating_text',
#                                             ''),
#                                            (u'Outdoor_Industry_Association_Political_Action_Committee_rating',
#                                             ''),
#                                            (u'Partnership_for_America_rating_text',
#                                             ''),
#                                            (u'Partnership_for_America_rating',
#                                             ''),
#                                            (u"Rachel's_Action_Network_rating_text",
#                                             ''),
#                                            (u"Rachel's_Action_Network_rating",
#                                             ''),
#                                            (u'Sierra_Club_rating_text', ''),
#                                            (u'Sierra_Club_rating', ''),
#                                            (u'Southern_Alliance_for_Clean_Energy_Action_Fund_rating_text',
#                                             ''),
#                                            (u'Southern_Alliance_for_Clean_Energy_Action_Fund_rating',
#                                             ''),
#                                            (u'Sunrise_Movement_rating_text',
#                                             ''),
#                                            (u'Sunrise_Movement_rating', ''),
#                                            (u'The_Climate_Mobilization_rating_text',
#                                             ''),
#                                            (u'The_Climate_Mobilization_rating',
#                                             ''),
#                                            (u'The_National_Wildlife_Federation_Action_Fund_rating_text',
#                                             ''),
#                                            (u'The_National_Wildlife_Federation_Action_Fund_rating',
#                                             ''),
#                                            (u'Western_Organization_of_Resource_Councils_rating_text',
#                                             ''),
#                                            (u'Western_Organization_of_Resource_Councils_rating',
#                                             ''),
#                                            (u"Women's_Action_for_New_Directions_(WAND)_rating_text",
#                                             ''),
#                                            (u"Women's_Action_for_New_Directions_(WAND)_rating",
#                                             ''),
#                                            (u'Zero_Hour_rating_text', ''),
#                                            (u'Zero_Hour_rating', ''),
#                                            (u'A Joint Resolution Providing for Congressional Disapproval under Chapter 8 of Title 5, United States Code, of a Rule Submitted by the Environmental Protection Agency Relating to "Carbon Pollution Emission Guidelines for Existing Stationary Sources: Electric Utility Generating Units"',
#                                             ''),
#                                            (u'Climate Action Now Act', ''),
#                                            (u'Arctic Cultural and Coastal Plain Protection Act',
#                                             ''),
#                                            (u'A joint resolution providing for congressional disapproval under chapter 8 of title 5, United States Code, of the rule submitted by the Environmental Protection Agency relating to "Repeal of the Clean Power Plan; Emission Guidelines for Greenhouse Gas Emissions From Existing Electric Utility Generating Units; Revisions to Emission Guidelines Implementing Regulations"',
#                                             '')]),
#                               OrderedDict([('name', u'Ayanna S. Pressley'),
#                                            ('office', u'U.S. House'),
#                                            ('state', u'MA'),
#                                            ('candidateId', u'122700'),
#                                            ('Positions', []),
#                                            (u'350_Action_rating_text', ''),
#                                            (u'350_Action_rating', ''),
#                                            (u'American_Forest_and_Paper_Association_rating_text',
#                                             ''),
#                                            (u'American_Forest_and_Paper_Association_rating',
#                                             ''),
#                                            (u'American_Lands_Alliance_rating_text',
#                                             ''),
#                                            (u'American_Lands_Alliance_rating',
#                                             ''),
#                                            (u'American_Society_of_Landscape_Architects_rating_text',
#                                             ''),
#                                            (u'American_Society_of_Landscape_Architects_rating',
#                                             ''),
#                                            (u'American_Wilderness_Coalition_rating_text',
#                                             ''),
#                                            (u'American_Wilderness_Coalition_rating',
#                                             ''),
#                                            (u'Associated_Equipment_Distributors_rating_text',
#                                             ''),
#                                            (u'Associated_Equipment_Distributors_rating',
#                                             ''),
#                                            (u'Brand_New_Congress_rating_text',
#                                             ''),
#                                            (u'Brand_New_Congress_rating', ''),
#                                            (u'Californians_for_Population_Stabilization_rating_text',
#                                             ''),
#                                            (u'Californians_for_Population_Stabilization_rating',
#                                             ''),
#                                            (u'Center_For_Biological_Diversity_Action_Fund_rating_text',
#                                             ''),
#                                            (u'Center_For_Biological_Diversity_Action_Fund_rating',
#                                             ''),
#                                            (u'Center_for_International_Policy_rating_text',
#                                             ''),
#                                            (u'Center_for_International_Policy_rating',
#                                             ''),
#                                            (u'Citizens_for_Global_Solutions_rating_text',
#                                             ''),
#                                            (u'Citizens_for_Global_Solutions_rating',
#                                             ''),
#                                            (u'Clean_Water_Action_rating_text',
#                                             ''),
#                                            (u'Clean_Water_Action_rating', ''),
#                                            (u'Climate_Hawks_Vote_rating_text',
#                                             ''),
#                                            (u'Climate_Hawks_Vote_rating', ''),
#                                            (u'Common_Defense_rating_text', ''),
#                                            (u'Common_Defense_rating', ''),
#                                            (u'Competitive_Enterprise_Institute_rating_text',
#                                             ''),
#                                            (u'Competitive_Enterprise_Institute_rating',
#                                             ''),
#                                            (u'ConservAmerica_rating_text', ''),
#                                            (u'ConservAmerica_rating', ''),
#                                            (u'Defenders_of_Wildlife_Action_Fund_rating_text',
#                                             ''),
#                                            (u'Defenders_of_Wildlife_Action_Fund_rating',
#                                             ''),
#                                            (u'Democratic_Socialists_Of_America_rating_text',
#                                             ''),
#                                            (u'Democratic_Socialists_Of_America_rating',
#                                             ''),
#                                            (u'EarthRights_International_rating_text',
#                                             ''),
#                                            (u'EarthRights_International_rating',
#                                             ''),
#                                            (u'Environment_America_rating_text',
#                                             ''),
#                                            (u'Environment_America_rating', ''),
#                                            (u'Food_Policy_Action_rating_text',
#                                             ''),
#                                            (u'Food_Policy_Action_rating', ''),
#                                            (u'Friends_of_the_Earth_Action_rating_text',
#                                             ''),
#                                            (u'Friends_of_the_Earth_Action_rating',
#                                             ''),
#                                            (u'Future_Now_Fund_rating_text',
#                                             ''),
#                                            (u'Future_Now_Fund_rating', ''),
#                                            (u'Global_Exchange_rating_text',
#                                             ''),
#                                            (u'Global_Exchange_rating', ''),
#                                            (u'Greenpeace_rating_text', ''),
#                                            (u'Greenpeace_rating', ''),
#                                            (u'League_of_Conservation_Voters_rating_text',
#                                             u'Representative Ayanna Pressley supported the interests of the League of Conservation Voters 97 percent in 2019.'),
#                                            (u'League_of_Conservation_Voters_rating',
#                                             u'97'),
#                                            (u'Matriarch_rating_text', ''),
#                                            (u'Matriarch_rating', ''),
#                                            (u'National_Parks_Conservation_Association_rating_text',
#                                             ''),
#                                            (u'National_Parks_Conservation_Association_rating',
#                                             ''),
#                                            (u'NextGen_America_rating_text',
#                                             ''),
#                                            (u'NextGen_America_rating', ''),
#                                            (u'Ocean_Champions_rating_text',
#                                             ''),
#                                            (u'Ocean_Champions_rating', ''),
#                                            (u'Outdoor_Industry_Association_Political_Action_Committee_rating_text',
#                                             ''),
#                                            (u'Outdoor_Industry_Association_Political_Action_Committee_rating',
#                                             ''),
#                                            (u'Partnership_for_America_rating_text',
#                                             ''),
#                                            (u'Partnership_for_America_rating',
#                                             ''),
#                                            (u"Rachel's_Action_Network_rating_text",
#                                             ''),
#                                            (u"Rachel's_Action_Network_rating",
#                                             ''),
#                                            (u'Sierra_Club_rating_text', ''),
#                                            (u'Sierra_Club_rating', ''),
#                                            (u'Southern_Alliance_for_Clean_Energy_Action_Fund_rating_text',
#                                             ''),
#                                            (u'Southern_Alliance_for_Clean_Energy_Action_Fund_rating',
#                                             ''),
#                                            (u'Sunrise_Movement_rating_text',
#                                             ''),
#                                            (u'Sunrise_Movement_rating', ''),
#                                            (u'The_Climate_Mobilization_rating_text',
#                                             ''),
#                                            (u'The_Climate_Mobilization_rating',
#                                             ''),
#                                            (u'The_National_Wildlife_Federation_Action_Fund_rating_text',
#                                             ''),
#                                            (u'The_National_Wildlife_Federation_Action_Fund_rating',
#                                             ''),
#                                            (u'Western_Organization_of_Resource_Councils_rating_text',
#                                             ''),
#                                            (u'Western_Organization_of_Resource_Councils_rating',
#                                             ''),
#                                            (u"Women's_Action_for_New_Directions_(WAND)_rating_text",
#                                             ''),
#                                            (u"Women's_Action_for_New_Directions_(WAND)_rating",
#                                             ''),
#                                            (u'Zero_Hour_rating_text', ''),
#                                            (u'Zero_Hour_rating', ''),
#                                            (u'A Joint Resolution Providing for Congressional Disapproval under Chapter 8 of Title 5, United States Code, of a Rule Submitted by the Environmental Protection Agency Relating to "Carbon Pollution Emission Guidelines for Existing Stationary Sources: Electric Utility Generating Units"',
#                                             ''),
#                                            (u'Climate Action Now Act', u'Yea'),
#                                            (u'Arctic Cultural and Coastal Plain Protection Act',
#                                             u'Yea'),
#                                            (u'A joint resolution providing for congressional disapproval under chapter 8 of title 5, United States Code, of the rule submitted by the Environmental Protection Agency relating to "Repeal of the Clean Power Plan; Emission Guidelines for Greenhouse Gas Emissions From Existing Electric Utility Generating Units; Revisions to Emission Guidelines Implementing Regulations"',
#                                             '')]),
#                               {'name': u'Lori Trahan'}])])]),
#              ('zip', '02125')])
